# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Scatter Plot**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# ## Overview
#
# In this lab, you will focus on creating and interpreting scatter plots to visualize relationships between variables and trends in the dataset. The provided dataset will be directly loaded into a pandas DataFrame, and various scatter plot-related visualizations will be created to explore developer trends, compensation, and preferences.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will:
#
# - Create and analyze scatter plots to examine relationships between variables.
#
# - Use scatter plots to identify trends and patterns in the dataset.
#
# - Focus on visualizations centered on scatter plots for better data-driven insights.

# %% [markdown]
# ## Setup: Working with the Database

# %% [markdown]
# **Install and import the required libraries**

# %%
# !pip install pandas
# !pip install matplotlib

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Step 1: Load the dataset

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"

df = pd.read_csv(file_path)

# %% [markdown]
# ### Task 1: Exploring Relationships with Scatter Plots

# %% [markdown]
# #### 1. Scatter Plot for Age vs. Job Satisfaction

# %% [markdown]
# Visualize the relationship between respondents' age (`Age`) and job satisfaction (`JobSatPoints_6`). Use this plot to identify any patterns or trends.

# %%
## Write your code here
df_subset = df[['Age', 'JobSatPoints_6']]
df_subset = df_subset.dropna()
df_subset['ConvertedCompYearly'] = pd.to_numeric(df_subset['Age'], errors='coerce')
df_subset['JobSatPoints_6'] = pd.to_numeric(df_subset['JobSatPoints_6'], errors='coerce')
plt.figure(figsize=(10, 6))
plt.scatter(df_subset['Age'], df_subset['JobSatPoints_6'], alpha=0.5)
plt.xlabel('Yearly Compensation')
plt.ylabel('Job Satisfaction Score (0-10)')
plt.title('Relationship Between Yearly Compensation and Job Satisfaction')
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Compensation vs. Job Satisfaction

# %% [markdown]
# Explore the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`) using a scatter plot.

# %%
## Write your code here
df = pd.read_csv(file_path)
df = df.dropna(subset=['ConvertedCompYearly', 'JobSatPoints_6'])  
df['ConvertedCompYearly'] = pd.to_numeric(df['ConvertedCompYearly'], errors='coerce').dropna()
df['JobSatPoints_6'] = pd.to_numeric(df['JobSatPoints_6'], errors='coerce').dropna()
plt.figure(figsize=(10, 6))
plt.scatter(df['ConvertedCompYearly'], df['JobSatPoints_6'], alpha=0.5)
plt.xlabel("Total Compensation")
plt.ylabel("Job Satisfaction (JobSatPoints_6)")
plt.title("Relationship between Total Compensation and Job Satisfaction")
plt.show()

# %% [markdown]
# ### Task 2: Enhancing Scatter Plots

# %% [markdown]
# #### 1. Scatter Plot with Trend Line for Age vs. Job Satisfaction

# %% [markdown]
# Add a regression line to the scatter plot of Age vs. JobSatPoints_6 to highlight trends in the data.

# %%
## Write your code here
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv(file_path)
df = df.dropna(subset=['Age', 'JobSatPoints_6'])  
df['Age'] = pd.to_numeric(df['ConvertedCompYearly'], errors='coerce').dropna()
df['JobSatPoints_6'] = pd.to_numeric(df['JobSatPoints_6'], errors='coerce').dropna()
x = df['Age']      
y = df['JobSatPoints_6']    
fit = np.polyfit(x, y, deg=1)
df.plot(kind='scatter', x='Age', y='JobSatPoints_6', figsize=(10, 6), color='darkblue')
plt.title('Distribution of Job Satisfaction for the Age')
plt.xlabel('Age')
plt.ylabel('JobSatPoints_6')
plt.plot(x, fit[0] * x + fit[1], color='gold') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[20], line 11
#       9 x = df['Age']
#      10 y = df['JobSatPoints_6']
# ---> 11 fit = np.polyfit(x, y, deg=1)
#      12 df.plot(kind='scatter', x='Age', y='JobSatPoints_6', figsize=(10, 6), color='darkblue')
#      13 plt.title('Distribution of Job Satisfaction for the Age')
#
# File /opt/conda/lib/python3.12/site-packages/numpy/lib/_polynomial_impl.py:666, in polyfit(x, y, deg, rcond, full, w, cov)
#     664 scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     665 lhs /= scale
# --> 666 c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     667 c = (c.T/scale).T  # broadcast scale coefficients
#     669 # warn on rank reduction, which indicates an ill conditioned matrix
#
# File /opt/conda/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2516, in lstsq(a, b, rcond)
# ...

# %% [markdown]
# #### 2. Scatter Plot for Age vs. Work Experience

# %% [markdown]
# Visualize the relationship between Age (`Age`) and Work Experience (`YearsCodePro`) using a scatter plot.

# %%
## Write your code here
df_subset = df[['Age', 'YearsCodePro']]
df_subset = df_subset.dropna()
df_subset['Age'] = pd.to_numeric(df_subset['Age'], errors='coerce')
df_subset['YearsCodePro'] = pd.to_numeric(df_subset['YearsCodePro'], errors='coerce')
plt.figure(figsize=(10, 6))
plt.scatter(df_subset['Age'], df_subset['YearsCodePro'], alpha=0.5)
plt.xlabel('YearsCodePro')
plt.ylabel('YearsCodePro')
plt.title('Relationship Between Age and YearsCodePro')
plt.show()

# %% [markdown]
# ### Task 3: Combining Scatter Plots with Additional Features

# %% [markdown]
# #### 1. Bubble Plot of Compensation vs. Job Satisfaction with Age as Bubble Size

# %% [markdown]
# Create a bubble plot to explore the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`), with bubble size representing age.

# %%
## Write your code here
plt.scatter(df['ConvertedCompYearly'], df['JobSatPoints_6'], s=df['Age']*10, alpha=0.5)
plt.xlabel('Yearly Compensation')
plt.ylabel('Job Satisfaction (1-6 scale)')
plt.title('Compensation vs. Job Satisfaction with Age as Bubble Size')
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Popular Programming Languages by Job Satisfaction

# %% [markdown]
# Visualize the popularity of programming languages (`LanguageHaveWorkedWith`) against job satisfaction using a scatter plot. Use points to represent satisfaction levels for each language.

# %%
## Write your code here
plt.figure(figsize=(10, 6)) # Adjust figure size if needed
plt.scatter(df["LanguageHaveWorkedWith"], df["JobSatPoints_6"], marker='o', s=100)
plt.xlabel('Language')
plt.ylabel('Job Satisfaction')
plt.title('Programming Languages: Language vs. Job Satisfaction')
plt.show()

# %% [markdown]
# ### Task 4: Scatter Plot Comparisons Across Groups

# %% [markdown]
# #### 1. Scatter Plot for Compensation vs. Job Satisfaction by Employment Type

# %% [markdown]
# Visualize the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSatPoints_6`), categorized by employment type (`Employment`). Use color coding or markers to differentiate between employment types.

# %%
## Write your code here
df = pd.read_csv(file_path) 
for employment_type in df['Employment'].unique():
    subset = df[df['Employment'] == employment_type]
    plt.scatter(subset['ConvertedCompYearly'], subset['JobSatPoints_6'],
                label=employment_type, marker='o')
plt.xlabel('Converted Compensation (Yearly)', fontsize=12)  
plt.ylabel('Job Satisfaction (Points_6)', fontsize=12)  
plt.title('Relationship between Compensation and Job Satisfaction by Employment Type', fontsize=14) 
plt.legend(loc='upper left', fontsize=10) 
plt.show()

# %% [markdown]
# #### 2. Scatter Plot for Work Experience vs. Age Group by Country

# %% [markdown]
# Compare work experience (`YearsCodePro`) across different age groups (`Age`) and countries (`Country`). Use colors to represent different countries and markers for age groups.

# %%
## Write your code here
df = pd.read_csv(file_path) 
for employment_type in df['Country'].unique():
    subset = df[df['Country'] == employment_type]
    plt.scatter(subset['YearsCodePro'], subset['Age'],
                label=employment_type, marker='o')
plt.xlabel('Years of Professional Code', fontsize=12)  
plt.ylabel('Age', fontsize=12)  
plt.title('Relationship between Years of Professionla Code and Age by Country Type', fontsize=14) 
plt.legend(loc='upper left', fontsize=10) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       3 for employment_type in df['Country'].unique():
#       4     subset = df[df['Country'] == employment_type]
# ----> 5     plt.scatter(subset['YearsCodePro'], subset['Age'],
#       6                 label=employment_type, marker='o')
#       7 plt.xlabel('Years of Professional Code', fontsize=12)
#       8 plt.ylabel('Age', fontsize=12)
#
# File /opt/conda/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
# ...

# %% [markdown]
# ### Final Step: Review

# %% [markdown]
# With these scatter plots, you will have analyzed data relationships across multiple dimensions, including compensation, job satisfaction, employment types, and demographics, to uncover meaningful trends in the developer community.

# %% [markdown]
# ### Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Analyze how numerical variables relate across specific groups, such as employment types and countries.
# - Use scatter plots effectively to represent multiple variables with color, size, and markers.
# - Gain insights into compensation, satisfaction, and demographic trends using advanced scatter plot techniques.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-07|1.2|Madhusudan Moole|Reviewed and updated lab|
# |2024-10-06|1.0|Raghul Ramesh|Created lab|-->

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
