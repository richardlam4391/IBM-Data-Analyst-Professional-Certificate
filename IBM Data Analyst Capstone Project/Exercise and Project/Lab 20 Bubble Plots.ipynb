# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Bubble Plots**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will focus on visualizing data.
#
# The dataset will be directly loaded into pandas for analysis and visualization.
#
# You will use various visualization techniques to explore the data and uncover key trends.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two data features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# #### Setup: Working with the Database
# **Install and import the needed libraries**

# %%
# !pip install pandas 
# !pip install matplotlib
# !pip install seaborn

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Download and connect to the database file containing survey data.**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows of the data to understand its structure
df.head()
# Out:
# --2026-02-20 16:07:01--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  36.2MB/s    in 4.2s
#
# 2026-02-20 16:07:06 (36.2 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# ...

# %% [markdown]
# ### Task 1: Exploring Data Distributions Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot for Age vs. Frequency of Participation

# %% [markdown]
# - Visualize the relationship between respondents’ age and their participation frequency (`SOPartFreq`) using a bubble plot.
#
# - Use the size of the bubbles to represent their job satisfaction (`JobSat`).

# %%
##Write your code here
plt.figure(figsize=(10, 6))
bubble_plot = sns.scatterplot(
    data=df, 
    x="Age", 
    y="SOPartFreq", 
    size="JobSat",   
    sizes=(50, 1000),     
    alpha=0.6,            
    legend='brief'
)
plt.title("Age vs. Participation Frequency", fontsize=15)
plt.xlabel("Age (Years)")
plt.ylabel("Frequency of Participation")
plt.show()

# %% [markdown]
# #### 2. Bubble Plot for Compensation vs. Job Satisfaction

# %% [markdown]
# -Visualize the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSat`).
#
# - Use the size of the bubbles to represent respondents’ age.

# %%
plt.figure(figsize=(12, 8))
bubble_plot = sns.scatterplot(
    data=df, 
    x="ConvertedCompYearly", 
    y="JobSat", 
    size="Age", 
    alpha=0.6,          
    sizes=(20, 1000)
)
plt.title("Compensation vs. Job Satisfaction", fontsize=16)
plt.xlabel("Annual Compensation ($)", fontsize=12)
plt.ylabel("Satisfaction Score", fontsize=12)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# ### Task 2: Analyzing Relationships Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot of Technology Preferences by Age
#
# - Visualize the popularity of programming languages respondents have worked with (`LanguageHaveWorkedWith`) across age groups.
#
# - Use bubble size to represent the frequency of each language.

# %%
plt.figure(figsize=(12, 8))
bubble_plot = sns.scatterplot(
    data=df, 
    x="ConvertedCompYearly", 
    y="JobSat", 
    size="Age", 
    alpha=0.6,          
    sizes=(20, 1000)
)
plt.title("Compensation vs. Job Satisfaction", fontsize=16)
plt.xlabel("Annual Compensation ($)", fontsize=12)
plt.ylabel("Satisfaction Score", fontsize=12)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# #### 2. Bubble Plot for Preferred Databases vs. Job Satisfaction
#
# - Explore the relationship between preferred databases (`DatabaseWantToWorkWith`) and job satisfaction.
#
# - Use bubble size to indicate the number of respondents for each database.

# %%
bubble_data = df.groupby(['DatabaseWantToWorkWith', 'JobSat']).size().reset_index(name='Count')
plt.figure(figsize=(12, 8))
scatter = plt.scatter(
    x=bubble_data['DatabaseWantToWorkWith'],
    y=bubble_data['JobSat'],
    s=bubble_data['Count'] * 50, 
    alpha=0.6,
    c=bubble_data['Count'],       
    cmap='viridis'
)
plt.title('Database Preference vs. Job Satisfaction', fontsize=16)
plt.xlabel('Preferred Database', fontsize=12)
plt.ylabel('Job Satisfaction (0-10)', fontsize=12)
plt.colorbar(scatter, label='User Count')
plt.show()

# %% [markdown]
# ### Task 3: Comparing Data Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot for Compensation Across Developer Roles
#
# - Visualize compensation (`ConvertedCompYearly`) across different developer roles (`DevType`).
#
# - Use bubble size to represent job satisfaction.

# %%
##Write your code here
bubble_plot = sns.scatterplot(
    data=df, 
    x="DevType", 
    y="ConvertedCompYearly", 
    size="JobSat", 
    legend=False, 
    sizes=(100, 2000), # Adjust bubble size range
    alpha=0.6, 
    color="blue"
)
plt.title("Compensation vs. Developer Roles", fontsize=16)
plt.xlabel("Developer Roles", fontsize=12)
plt.ylabel("Compensation", fontsize=12)
plt.show()

# %% [markdown]
# #### 2. Bubble Plot for Collaboration Tools by Age
#
# - Visualize the relationship between the collaboration tools used (`NEWCollabToolsHaveWorkedWith`) and age groups.
#
# - Use bubble size to represent the frequency of tool usage.

# %%
bubble_data1 = df.groupby(['NEWCollabToolsHaveWorkedWith', 'Age']).size().reset_index(name='Count')
plt.figure(figsize=(12, 8))
scatter = plt.scatter(
    x=bubble_data1['NEWCollabToolsHaveWorkedWith'], 
    y=bubble_data1['Age'], 
    s=bubble_data1['Count'] * 50,  # Adjust multiplier if bubbles are too big/small
    alpha=0.6, 
    c=bubble_data1['Count'], 
    cmap='viridis'
)
plt.title('Collaboration Tools vs. Age', fontsize=16)
plt.xlabel('Collaboration Tools', fontsize=12)
plt.ylabel('Age', fontsize=12)
plt.colorbar(scatter, label='User Count')
plt.show()

# %% [markdown]
# ### Task 4: Visualizing Technology Trends Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot for Preferred Web Frameworks vs. Job Satisfaction
#
# - Explore the relationship between preferred web frameworks (`WebframeWantToWorkWith`) and job satisfaction.
#
# - Use bubble size to represent the number of respondents.

# %%
bubble_data2 = df.groupby(['WebframeWantToWorkWith', 'JobSat']).size().reset_index(name='Count')
plt.figure(figsize=(12, 8))
scatter = plt.scatter(
    x=bubble_data2['WebframeWantToWorkWith'], 
    y=bubble_data2['JobSat'], 
    s=bubble_data2['Count'] * 50,  
    alpha=0.6, 
    c=bubble_data2['Count'], 
    cmap='viridis'
)
plt.title('Web Frameworks vs. Job Satisfaction', fontsize=16)
plt.xlabel('Web Frameworks', fontsize=12)
plt.ylabel('Job Satisfaction', fontsize=12)
plt.colorbar(scatter, label='User Count')
plt.show()

# %% [markdown]
# #### 2. Bubble Plot for Admired Technologies Across Countries
#
# - Visualize the distribution of admired technologies (`LanguageAdmired`) across different countries (`Country`).
#
# - Use bubble size to represent the frequency of admiration.

# %%
bubble_data3 = df.groupby(['LanguageAdmired', 'Country']).size().reset_index(name='Count')
plt.figure(figsize=(12, 8))
scatter = plt.scatter(
    x=bubble_data3['LanguageAdmired'], 
    y=bubble_data3['Country'], 
    s=bubble_data3['Count'] * 50,  
    alpha=0.6, 
    c=bubble_data3['Count'], 
    cmap='viridis'
)
plt.title('Distribution of Admired Technologies by Country', fontsize=16)
plt.xlabel('Admired Technologies', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.colorbar(scatter, label='User Count')
plt.show()

# %% [markdown]
# ## Final Step: Review

# %% [markdown]
# After completing the lab, you will have extensively used bubble plots to gain insights into developer community preferences, demographics, compensation trends, and job satisfaction.

# %% [markdown]
# ## Summary

# %% [markdown]
# After completing this lab, you will be able to:
#
# - Create and interpret bubble plots to analyze relationships and compositions within datasets.
#
# - Use bubble plots to explore developer preferences, compensation trends, and satisfaction levels.
#
# - Apply bubble plots to visualize complex relationships involving multiple dimensions effectively.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-29|1.2|Madhusudhan Moole|Updated lab|
# |2024-10-16|1.1|Madhusudhan Moole|Updated lab|
# |2024-10-15|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
