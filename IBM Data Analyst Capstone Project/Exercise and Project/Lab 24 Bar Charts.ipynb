# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Bar Charts**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will focus on visualizing data.
#
# The dataset will be provided to you in the form of an RDBMS.
#
# You will use SQL queries to extract the necessary data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data
#
# -   Visualize the relationship between two features
#
# -   Visualize the composition of data
#
# -   Visualize comparison of data

# %% [markdown]
# ## Setup: Working with the Database
# **Install the needed libraries**

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
# !pip install seaborn

# %%
# !pip install numpy

# %% [markdown]
# **Download and connect to the database file containing survey data.**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
# !wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Step 2: Import necessary libraries and load the dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the data
df = pd.read_csv("survey-data.csv")

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# --2026-04-07 01:16:53--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 159525875 (152M) [text/csv]
# Saving to: ‘survey-data.csv’
#
# survey-data.csv     100%[===================>] 152.13M  43.0MB/s    in 3.7s
#
# 2026-04-07 01:16:57 (40.7 MB/s) - ‘survey-data.csv’ saved [159525875/159525875]
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# ...

# %% [markdown]
# ### Task 1: Visualizing Data Distributions

# %% [markdown]
# ##### 1. Histogram of `ConvertedCompYearly`

# %% [markdown]
# Visualize the distribution of yearly compensation (`ConvertedCompYearly`) using a histogram.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='ConvertedCompYearly', kde=True, log_scale=True)
plt.title('Distribution of Yearly Compensation')
plt.xlabel('Yearly Compensation (USD)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 2. Box Plot of `Age`

# %% [markdown]
# Since `Age` is categorical in the dataset, convert it to numerical values for a box plot.

# %%
sns.boxplot(data=df, y='Age')
plt.title('Distribution of Age')
plt.show()

# %% [markdown]
# ### Task 2: Visualizing Relationships in Data

# %% [markdown]
# ##### 1. Scatter Plot of `Age_numeric` and `ConvertedCompYearly`

# %% [markdown]
# Explore the relationship between age and compensation.

# %%
df['Age_numeric'] = df['Age'].str.extract(r'(\d+)-(\d+)').astype(float).mean(axis=1)
df.loc[df['Age'].str.contains('Under 18', na=False), 'Age_numeric'] = 17
df.loc[df['Age'].str.contains('65', na=False), 'Age_numeric'] = 70
df['ConvertedCompYearly'] = pd.to_numeric(df['ConvertedCompYearly'], errors='coerce')
plot_df = df.dropna(subset=['Age_numeric', 'ConvertedCompYearly'])
x, y = plot_df['Age_numeric'], plot_df['ConvertedCompYearly']
m, b = np.polyfit(x, y, 1)
plt.figure(figsize=(10, 6))
plt.scatter(x, y, alpha=0.3, label='Data Points')
plt.plot(x, m*x + b, color='red', linewidth=2, label='Trendline') # Add regression line
plt.title('Age vs Yearly Compensation')
plt.xlabel('Age (Numeric)')
plt.ylabel('Compensation (USD)')
plt.legend()
plt.show()

# %% [markdown]
# ##### 2. Bubble Plot of `ConvertedCompYearly` and `JobSatPoints_6` with `Age_numeric` as Bubble Size

# %% [markdown]
# Explore how compensation and job satisfaction are related, with age as the bubble size.

# %%
df = df.dropna(subset=['ConvertedCompYearly', 'JobSatPoints_6', 'Age_numeric'])
df = df[df['ConvertedCompYearly'] > 0]
Q1 = df['ConvertedCompYearly'].quantile(0.25)
Q3 = df['ConvertedCompYearly'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR
df_clean = df[df['ConvertedCompYearly'] <= upper_bound]
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=df_clean,
    x='JobSatPoints_6',
    y='ConvertedCompYearly',
    size='Age_numeric',
    sizes=(20, 500),
    alpha=0.6,
    legend='brief'
)
plt.title(f'Compensation vs. Job Satisfaction (Filtered < ${upper_bound:,.0f})', fontsize=14)
plt.xlabel('Job Satisfaction Points (1-6)', fontsize=12)
plt.ylabel('Yearly Compensation (USD)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 3: Visualizing Composition of Data with Bar Charts

# %% [markdown]
# ##### 1. Horizontal Bar Chart of `MainBranch` Distribution

# %% [markdown]
# Visualize the distribution of respondents’ primary roles to understand their professional focus.

# %%
branch_counts = df['MainBranch'].value_counts().reset_index()
branch_counts.columns = ['MainBranch', 'Count']
plt.figure(figsize=(10, 6))
sns.barplot(data=branch_counts, x='Count', y='MainBranch', hue='MainBranch', palette='viridis', legend=False)
plt.title('Distribution of MainBranch (Stack Overflow Survey)')
plt.xlabel('Number of Respondents')
plt.ylabel('Branch Type')
plt.show()

# %% [markdown]
# ##### 2. Vertical Bar Chart of Top 5 Programming Languages Respondents Want to Work With

# %% [markdown]
# Identify the most desired programming languages based on `LanguageWantToWorkWith`.

# %%
LanguageWantToWorkWith_counts = df['LanguageWantToWorkWith'].value_counts().reset_index().head()
LanguageWantToWorkWith_counts.columns = ['LanguageWantToWorkWith', 'Count']
plt.figure(figsize=(10, 6))
sns.barplot(data=LanguageWantToWorkWith_counts, x='Count', y='LanguageWantToWorkWith', legend=False)
plt.title('Distribution of LanguageWantToWorkWith')
plt.xlabel('Number of Respondents')
plt.ylabel('LanguageWantToWorkWith')
plt.show()

# %% [markdown]
# Compare job satisfaction metrics across different age groups with a stacked bar chart.

# %%
df = df.dropna(subset=['Age_numeric', 'JobSatPoints_6']) 
pivot_df = df.groupby(['Age_numeric', 'JobSatPoints_6']).size().unstack(fill_value=0)
ax = pivot_df.plot(kind='bar', stacked=True, figsize=(15, 7), width=0.8)
plt.title('Job Satisfaction by Specific Age')
plt.xlabel('Age (Numeric)')
plt.ylabel('Count')
plt.legend(title='Satisfaction')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1160/1536618321.py:8: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ##### 4. Bar Chart of Database Popularity (`DatabaseHaveWorkedWith`)

# %% [markdown]
# Identify the most commonly used databases among respondents by visualizing `DatabaseHaveWorkedWith`.

# %%
## Write your code here
df = pd.read_csv("survey-data.csv")
database_data = df['DatabaseWantToWorkWith'].dropna()  
database_counts = database_data.str.split(';', expand=True).stack().str.strip().value_counts()
top_database = database_counts.head(5)
plt.figure(figsize=(10, 6)) 
plt.bar(top_database.index, top_database.values)
plt.xlabel("Database")
pltaba_label="Database"
plt.ylabel("Number of Respondents")
plt.title("Top 5 Desired Database Respondents Want to Work With")
plt.xticks(rotation=45, ha='right') 
plt.tight_layout()  
plt.show()

# %% [markdown]
# ### Task 4: Visualizing Comparison of Data with Bar Charts

# %% [markdown]
# ##### 1. Grouped Bar Chart of Median `ConvertedCompYearly` for Different Age Groups

# %% [markdown]
# Compare median compensation across multiple age groups with a grouped bar chart.

# %%
## Write your code here
median_by_age = df.groupby('Age')['ConvertedCompYearly'].median().reset_index()
plt.figure(figsize=(14, 6))
sns.barplot(data=median_by_age, x='Age', y='ConvertedCompYearly', color='blue')
plt.title('Median Yearly Compensation by Exact Numeric Age')
plt.xlabel('Age (Years)')
plt.ylabel('Median Compensation (USD)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 2. Bar Chart of Respondent Count by Country

# %% [markdown]
# Show the distribution of respondents by country to see which regions are most represented.

# %%
## Write your code here
country_counts = df['Country'].value_counts().sort_values(ascending=False) 
top_country = country_counts.head(10)
plt.figure(figsize=(10, 6))  
plt.bar(top_country.index, top_country.values)
plt.xlabel('Country')
plt.ylabel('Number of Respondents')
plt.title('Distribution of Respondents by Country')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Final Step: Review

# %% [markdown]
# This lab demonstrates how to create and interpret different types of bar charts, allowing you to analyze the composition, comparison, and distribution of categorical data in the Stack Overflow dataset, including main professional branches, programming language preferences, and compensation by age group. Bar charts effectively compare counts and median values across various categories.

# %% [markdown]
# ## Summary

# %% [markdown]
# After completing this lab, you will be able to:
# - Create a horizontal bar chart to visualize the distribution of respondents' primary roles, helping to understand their professional focus.
# - Develop a vertical bar chart to identify the most desired programming languages based on the LanguageWantToWorkWith variable.
# - Use a stacked bar chart to compare job satisfaction metrics across different age groups.
# - Create a bar chart to visualize the most commonly used databases among respondents using the DatabaseHaveWorkedWith variable.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
