# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Impute Missing Values**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will practice essential data wrangling techniques using the Stack Overflow survey dataset. The primary focus is on handling missing data and ensuring data quality. You will:
#
# - **Load the Data:** Import the dataset into a DataFrame using the pandas library.
#
# - **Clean the Data:** Identify and remove duplicate entries to maintain data integrity.
#
# - **Handle Missing Values:** Detect missing values, impute them with appropriate strategies, and verify the imputation to create a complete and reliable dataset for analysis.
#
# This lab equips you with the skills to effectively preprocess and clean real-world datasets, a crucial step in any data analysis project.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# -   Identify missing values in the dataset.
#
# -   Apply techniques to impute missing values in the dataset.
#
# -   Use suitable techniques to normalize data in the dataset.

# %% [markdown]
# -----

# %% [markdown]
# #### Install needed library

# %%
# !pip install pandas
# !pip matplotlib
# !pip seaborn
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# ERROR: unknown command "matplotlib"
# ERROR: unknown command "seaborn" - maybe you meant "search"

# %% [markdown]
# ### Step 1: Import Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ### Step 2: Load the Dataset Into a Dataframe

# %% [markdown]
# #### **Read Data**
# <p>
# The functions below will download the dataset into your browser:
# </p>

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"
df = pd.read_csv(file_path)

# Display the first few rows to ensure it loaded correctly
print(df.head())

# %% [markdown]
# ### Step 3. Finding and Removing Duplicates
# ##### Task 1: Identify duplicate rows in the dataset.

# %%
## Write your code here
duplicate = df.duplicated()
duplicate

# %% [markdown]
# ##### Task 2: Remove the duplicate rows from the dataframe.

# %%
## Write your code here
df_no_duplicate = df.drop_duplicates()
df_no_duplicate

# %% [markdown]
# ### Step 4: Finding Missing Values
# ##### Task 3: Find the missing values for all columns.

# %%
## Write your code here
missing_values = df.isnull().sum()
missing_values
# Out:
# ResponseId                 0
# MainBranch                 0
# Age                        0
# Employment                 0
# RemoteWork                 0
#                        ...
# JobSatPoints_11        35992
# SurveyLength            9255
# SurveyEase              9199
# ConvertedCompYearly    42002
# JobSat                 36311
# Length: 114, dtype: int64

# %% [markdown]
# ##### Task 4: Find out how many rows are missing in the column RemoteWork.

# %%
## Write your code here
Remote_Work_missing_count = df["RemoteWork"].isnull().sum()
Remote_Work_missing_count
# Out:
# np.int64(0)

# %% [markdown]
# ### Step 5. Imputing Missing Values
# ##### Task 5: Find the value counts for the column RemoteWork.

# %%
## Write your code here
Remote_Work_value_counts = df["RemoteWork"].value_counts()
Remote_Work_value_counts
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    33646
# Remote                                  20831
# In-person                               10960
# Name: count, dtype: int64

# %% [markdown]
# ##### Task 6: Identify the most frequent (majority) value in the RemoteWork column.

# %%
## Write your code here
Remote_Work_most_frequent = df["RemoteWork"].mode()[0]
Remote_Work_most_frequent
# Out:
# 'Hybrid (some remote, some in-person)'

# %% [markdown]
# ##### Task 7: Impute (replace) all the empty rows in the column RemoteWork with the majority value.

# %%
## Write your code here
df["RemoteWork"].fillna(Remote_Work_value_counts, inplace=True)
print(df["RemoteWork"].to_string())
# Out:
# 0                                      Remote
# 1                                      Remote
# 2                                      Remote
# 3        Hybrid (some remote, some in-person)
# 4        Hybrid (some remote, some in-person)
# 5        Hybrid (some remote, some in-person)
# 6                                      Remote
# 7        Hybrid (some remote, some in-person)
# 8                                   In-person
# 9                                      Remote
# 10                                     Remote
# 11                                  In-person
# 12       Hybrid (some remote, some in-person)
# 13       Hybrid (some remote, some in-person)
# 14       Hybrid (some remote, some in-person)
# 15       Hybrid (some remote, some in-person)
# 16       Hybrid (some remote, some in-person)
# 17                                     Remote
# 18       Hybrid (some remote, some in-person)
# 19       Hybrid (some remote, some in-person)
# 20       Hybrid (some remote, some in-person)
# 21                                  In-person
# 22                                     Remote
# 23       Hybrid (some remote, some in-person)
# 24                                     Remote
# 25       Hybrid (some remote, some in-person)
# 26                                     Remote
# 27                                     Remote
# 28                                     Remote
# 29                                     Remote
# 30       Hybrid (some remote, some in-person)
# 31       Hybrid (some remote, some in-person)
# 32                                  In-person
# 33       Hybrid (some remote, some in-person)
# 34       Hybrid (some remote, some in-person)
# 35                                     Remote
# 36                                     Remote
# 37                                     Remote
# 38                                     Remote
# 39       Hybrid (some remote, some in-person)
# 40                                     Remote
# 41                                     Remote
# 42                                     Remote
# 43                                  In-person
# 44       Hybrid (some remote, some in-person)
# 45                                     Remote
# 46       Hybrid (some remote, some in-person)
# 47       Hybrid (some remote, some in-person)
# 48                                     Remote
# 49                                     Remote
# 50       Hybrid (some remote, some in-person)
# 51       Hybrid (some remote, some in-person)
# 52       Hybrid (some remote, some in-person)
# 53                                  In-person
# 54       Hybrid (some remote, some in-person)
# 55                                  In-person
# 56       Hybrid (some remote, some in-person)
# 57                                     Remote
# 58       Hybrid (some remote, some in-person)
# 59       Hybrid (some remote, some in-person)
# 60       Hybrid (some remote, some in-person)
# 61       Hybrid (some remote, some in-person)
# 62       Hybrid (some remote, some in-person)
# 63       Hybrid (some remote, some in-person)
# 64       Hybrid (some remote, some in-person)
# 65       Hybrid (some remote, some in-person)
# 66       Hybrid (some remote, some in-person)
# 67       Hybrid (some remote, some in-person)
# 68       Hybrid (some remote, some in-person)
# 69                                     Remote
# 70       Hybrid (some remote, some in-person)
# 71       Hybrid (some remote, some in-person)
# 72       Hybrid (some remote, some in-person)
# 73                                  In-person
# 74       Hybrid (some remote, some in-person)
# 75       Hybrid (some remote, some in-person)
# 76                                     Remote
# 77       Hybrid (some remote, some in-person)
# 78                                     Remote
# 79                                     Remote
# 80       Hybrid (some remote, some in-person)
# 81       Hybrid (some remote, some in-person)
# 82                                     Remote
# 83                                     Remote
# 84       Hybrid (some remote, some in-person)
# 85       Hybrid (some remote, some in-person)
# 86       Hybrid (some remote, some in-person)
# 87       Hybrid (some remote, some in-person)
# 88       Hybrid (some remote, some in-person)
# 89                                  In-person
# 90       Hybrid (some remote, some in-person)
# 91       Hybrid (some remote, some in-person)
# 92       Hybrid (some remote, some in-person)
# 93       Hybrid (some remote, some in-person)
# 94       Hybrid (some remote, some in-person)
# 95                                  In-person
# 96                                     Remote
# 97       Hybrid (some remote, some in-person)
# 98       Hybrid (some remote, some in-person)
# 99       Hybrid (some remote, some in-person)
# 100                                    Remote
# 101                                 In-person
# 102                                    Remote
# 103      Hybrid (some remote, some in-person)
# 104      Hybrid (some remote, some in-person)
# 105                                    Remote
# 106      Hybrid (some remote, some in-person)
# 107                                 In-person
# 108      Hybrid (some remote, some in-person)
# 109      Hybrid (some remote, some in-person)
# 110      Hybrid (some remote, some in-person)
# 111      Hybrid (some remote, some in-person)
# 112      Hybrid (some remote, some in-person)
# 113      Hybrid (some remote, some in-person)
# 114                                    Remote
# 115      Hybrid (some remote, some in-person)
# 116      Hybrid (some remote, some in-person)
# 117                                    Remote
# 118      Hybrid (some remote, some in-person)
# 119                                    Remote
# 120      Hybrid (some remote, some in-person)
# 121      Hybrid (some remote, some in-person)
# 122      Hybrid (some remote, some in-person)
# 123      Hybrid (some remote, some in-person)
# 124                                    Remote
# 125      Hybrid (some remote, some in-person)
# 126      Hybrid (some remote, some in-person)
# 127                                    Remote
# 128                                    Remote
# 129                                 In-person
# 130                                    Remote
# 131      Hybrid (some remote, some in-person)
# 132                                    Remote
# 133      Hybrid (some remote, some in-person)
# 134      Hybrid (some remote, some in-person)
# 135      Hybrid (some remote, some in-person)
# 136      Hybrid (some remote, some in-person)
# 137      Hybrid (some remote, some in-person)
# 138      Hybrid (some remote, some in-person)
# 139      Hybrid (some remote, some in-person)
# 140      Hybrid (some remote, some in-person)
# 141                                 In-person
# 142      Hybrid (some remote, some in-person)
# 143      Hybrid (some remote, some in-person)
# 144      Hybrid (some remote, some in-person)
# 145      Hybrid (some remote, some in-person)
# 146      Hybrid (some remote, some in-person)
# 147      Hybrid (some remote, some in-person)
# 148                                    Remote
# 149                                    Remote
# 150                                    Remote
# 151      Hybrid (some remote, some in-person)
# 152      Hybrid (some remote, some in-person)
# 153                                    Remote
# 154      Hybrid (some remote, some in-person)
# 155                                    Remote
# 156      Hybrid (some remote, some in-person)
# 157                                 In-person
# 158      Hybrid (some remote, some in-person)
# 159                                    Remote
# 160      Hybrid (some remote, some in-person)
# 161                                    Remote
# 162                                    Remote
# 163      Hybrid (some remote, some in-person)
# 164      Hybrid (some remote, some in-person)
# 165                                    Remote
# 166                                 In-person
# 167      Hybrid (some remote, some in-person)
# 168      Hybrid (some remote, some in-person)
# 169                                 In-person
# 170                                    Remote
# 171                                    Remote
# 172                                    Remote
# 173      Hybrid (some remote, some in-person)
# 174      Hybrid (some remote, some in-person)
# 175                                 In-person
# 176      Hybrid (some remote, some in-person)
# 177      Hybrid (some remote, some in-person)
# 178      Hybrid (some remote, some in-person)
# 179      Hybrid (some remote, some in-person)
# 180      Hybrid (some remote, some in-person)
# 181                                    Remote
# 182                                    Remote
# 183                                    Remote
# 184                                    Remote
# 185      Hybrid (some remote, some in-person)
# 186                                 In-person
# 187                                    Remote
# 188                                    Remote
# 189      Hybrid (some remote, some in-person)
# 190                                    Remote
# 191      Hybrid (some remote, some in-person)
# 192                                    Remote
# 193      Hybrid (some remote, some in-person)
# 194                                 In-person
# 195      Hybrid (some remote, some in-person)
# 196                                 In-person
# 197      Hybrid (some remote, some in-person)
# 198      Hybrid (some remote, some in-person)
# 199                                    Remote
# 200      Hybrid (some remote, some in-person)
# 201                                 In-person
# 202      Hybrid (some remote, some in-person)
# 203      Hybrid (some remote, some in-person)
# 204                                    Remote
# 205      Hybrid (some remote, some in-person)
# 206                                    Remote
# 207                                    Remote
# 208                                 In-person
# 209      Hybrid (some remote, some in-person)
# 210      Hybrid (some remote, some in-person)
# 211      Hybrid (some remote, some in-person)
# 212      Hybrid (some remote, some in-person)
# 213      Hybrid (some remote, some in-person)
# 214                                    Remote
# 215      Hybrid (some remote, some in-person)
# 216      Hybrid (some remote, some in-person)
# 217                                    Remote
# 218      Hybrid (some remote, some in-person)
# 219      Hybrid (some remote, some in-person)
# 220      Hybrid (some remote, some in-person)
# 221                                 In-person
# 222      Hybrid (some remote, some in-person)
# 223      Hybrid (some remote, some in-person)
# 224                                    Remote
# 225                                    Remote
# 226                                    Remote
# 227      Hybrid (some remote, some in-person)
# 228      Hybrid (some remote, some in-person)
# 229                                    Remote
# 230      Hybrid (some remote, some in-person)
# 231                                 In-person
# 232                                    Remote
# 233                                    Remote
# 234                                    Remote
# 235                                    Remote
# 236                                    Remote
# 237                                 In-person
# 238                                    Remote
# 239      Hybrid (some remote, some in-person)
# 240                                 In-person
# 241                                 In-person
# 242                                 In-person
# 243      Hybrid (some remote, some in-person)
# 244                                 In-person
# 245                                    Remote
# 246      Hybrid (some remote, some in-person)
# 247      Hybrid (some remote, some in-person)
# 248                                    Remote
# 249      Hybrid (some remote, some in-person)
# 250                                    Remote
# 251                                 In-person
# 252                                    Remote
# 253      Hybrid (some remote, some in-person)
# 254                                 In-person
# 255      Hybrid (some remote, some in-person)
# 256                                 In-person
# 257      Hybrid (some remote, some in-person)
# 258      Hybrid (some remote, some in-person)
# 259      Hybrid (some remote, some in-person)
# 260                                    Remote
# 261      Hybrid (some remote, some in-person)
# 262      Hybrid (some remote, some in-person)
# 263      Hybrid (some remote, some in-person)
# 264      Hybrid (some remote, some in-person)
# 265                                    Remote
# 266      Hybrid (some remote, some in-person)
# 267      Hybrid (some remote, some in-person)
# 268                                    Remote
# 269      Hybrid (some remote, some in-person)
# 270                                    Remote
# 271      Hybrid (some remote, some in-person)
# 272      Hybrid (some remote, some in-person)
# 273      Hybrid (some remote, some in-person)
# 274                                    Remote
# 275                                    Remote
# 276      Hybrid (some remote, some in-person)
# 277      Hybrid (some remote, some in-person)
# 278      Hybrid (some remote, some in-person)
# 279                                    Remote
# 280                                    Remote
# 281      Hybrid (some remote, some in-person)
# 282      Hybrid (some remote, some in-person)
# 283      Hybrid (some remote, some in-person)
# 284      Hybrid (some remote, some in-person)
# 285                                    Remote
# 286      Hybrid (some remote, some in-person)
# 287      Hybrid (some remote, some in-person)
# 288                                    Remote
# 289      Hybrid (some remote, some in-person)
# 290      Hybrid (some remote, some in-person)
# 291                                 In-person
# 292      Hybrid (some remote, some in-person)
# 293      Hybrid (some remote, some in-person)
# 294      Hybrid (some remote, some in-person)
# 295      Hybrid (some remote, some in-person)
# 296                                    Remote
# 297                                 In-person
# 298                                 In-person
# 299                                    Remote
# 300                                    Remote
# 301      Hybrid (some remote, some in-person)
# 302                                    Remote
# 303      Hybrid (some remote, some in-person)
# 304                                    Remote
# 305      Hybrid (some remote, some in-person)
# 306      Hybrid (some remote, some in-person)
# 307      Hybrid (some remote, some in-person)
# 308      Hybrid (some remote, some in-person)
# 309      Hybrid (some remote, some in-person)
# 310      Hybrid (some remote, some in-person)
# 311      Hybrid (some remote, some in-person)
# 312                                 In-person
# 313                                    Remote
# 314      Hybrid (some remote, some in-person)
# 315                                 In-person
# 316                                 In-person
# 317                                 In-person
# 318                                 In-person
# 319      Hybrid (some remote, some in-person)
# 320      Hybrid (some remote, some in-person)
# 321      Hybrid (some remote, some in-person)
# 322                                    Remote
# 323      Hybrid (some remote, some in-person)
# 324      Hybrid (some remote, some in-person)
# 325                                    Remote
# 326                                    Remote
# 327      Hybrid (some remote, some in-person)
# 328      Hybrid (some remote, some in-person)
# 329                                    Remote
# 330                                 In-person
# 331                                 In-person
# 332      Hybrid (some remote, some in-person)
# 333      Hybrid (some remote, some in-person)
# 334      Hybrid (some remote, some in-person)
# 335      Hybrid (some remote, some in-person)
# 336                                 In-person
# 337      Hybrid (some remote, some in-person)
# 338                                    Remote
# 339                                 In-person
# 340                                    Remote
# 341                                    Remote
# 342                                    Remote
# 343                                 In-person
# 344                                    Remote
# 345                                    Remote
# 346                                    Remote
# 347      Hybrid (some remote, some in-person)
# 348      Hybrid (some remote, some in-person)
# 349      Hybrid (some remote, some in-person)
# 350                                    Remote
# 351      Hybrid (some remote, some in-person)
# 352                                    Remote
# 353      Hybrid (some remote, some in-person)
# 354      Hybrid (some remote, some in-person)
# 355      Hybrid (some remote, some in-person)
# 356                                    Remote
# 357                                    Remote
# 358                                    Remote
# 359                                    Remote
# 360                                    Remote
# 361      Hybrid (some remote, some in-person)
# 362                                    Remote
# 363      Hybrid (some remote, some in-person)
# 364                                    Remote
# 365      Hybrid (some remote, some in-person)
# 366                                    Remote
# 367                                    Remote
# 368      Hybrid (some remote, some in-person)
# 369                                    Remote
# 370                                    Remote
# 371                                    Remote
# 372                                 In-person
# 373      Hybrid (some remote, some in-person)
# 374      Hybrid (some remote, some in-person)
# 375      Hybrid (some remote, some in-person)
# 376      Hybrid (some remote, some in-person)
# 377      Hybrid (some remote, some in-person)
# 378                                    Remote
# 379                                    Remote
# 380                                 In-person
# 381                                    Remote
# 382      Hybrid (some remote, some in-person)
# 383                                 In-person
# 384                                    Remote
# 385                                    Remote
# 386                                    Remote
# 387                                    Remote
# 388                                    Remote
# 389                                    Remote
# 390                                    Remote
# 391                                    Remote
# 392      Hybrid (some remote, some in-person)
# 393                                    Remote
# 394                                 In-person
# 395                                    Remote
# 396      Hybrid (some remote, some in-person)
# 397                                    Remote
# 398                                    Remote
# 399                                    Remote
# 400      Hybrid (some remote, some in-person)
# 401      Hybrid (some remote, some in-person)
# 402      Hybrid (some remote, some in-person)
# 403                                    Remote
# 404                                 In-person
# 405                                 In-person
# 406      Hybrid (some remote, some in-person)
# 407                                 In-person
# 408                                    Remote
# 409                                 In-person
# 410                                    Remote
# 411      Hybrid (some remote, some in-person)
# 412                                    Remote
# 413                                    Remote
# 414                                    Remote
# 415                                    Remote
# 416                                    Remote
# 417                                 In-person
# 418      Hybrid (some remote, some in-person)
# 419      Hybrid (some remote, some in-person)
# 420      Hybrid (some remote, some in-person)
# 421                                 In-person
# 422                                 In-person
# 423                                    Remote
# 424                                    Remote
# 425                                    Remote
# 426                                    Remote
# 427                                    Remote
# 428                                    Remote
# 429      Hybrid (some remote, some in-person)
# 430                                    Remote
# 431                                 In-person
# 432                                    Remote
# 433                                    Remote
# 434                                    Remote
# 435                                    Remote
# 436                                    Remote
# 437      Hybrid (some remote, some in-person)
# 438      Hybrid (some remote, some in-person)
# 439      Hybrid (some remote, some in-person)
# 440                                    Remote
# 441                                 In-person
# 442                                 In-person
# 443                                    Remote
# 444                                    Remote
# 445                                 In-person
# 446      Hybrid (some remote, some in-person)
# 447                                 In-person
# 448                                    Remote
# 449      Hybrid (some remote, some in-person)
# 450      Hybrid (some remote, some in-person)
# 451                                    Remote
# 452      Hybrid (some remote, some in-person)
# 453                                 In-person
# 454      Hybrid (some remote, some in-person)
# 455      Hybrid (some remote, some in-person)
# 456      Hybrid (some remote, some in-person)
# 457      Hybrid (some remote, some in-person)
# 458      Hybrid (some remote, some in-person)
# 459                                 In-person
# 460                                 In-person
# 461      Hybrid (some remote, some in-person)
# 462                                    Remote
# 463                                 In-person
# 464                                 In-person
# 465      Hybrid (some remote, some in-person)
# 466      Hybrid (some remote, some in-person)
# 467                                    Remote
# 468      Hybrid (some remote, some in-person)
# 469                                    Remote
# 470                                    Remote
# 471      Hybrid (some remote, some in-person)
# 472                                 In-person
# 473                                 In-person
# 474                                    Remote
# 475      Hybrid (some remote, some in-person)
# 476                                    Remote
# 477                                    Remote
# 478                                 In-person
# 479      Hybrid (some remote, some in-person)
# 480      Hybrid (some remote, some in-person)
# 481                                 In-person
# 482                                    Remote
# 483                                    Remote
# 484      Hybrid (some remote, some in-person)
# 485                                    Remote
# 486      Hybrid (some remote, some in-person)
# 487      Hybrid (some remote, some in-person)
# 488                                    Remote
# 489      Hybrid (some remote, some in-person)
# 490                                 In-person
# 491                                    Remote
# 492      Hybrid (some remote, some in-person)
# 493                                    Remote
# 494                                    Remote
# 495      Hybrid (some remote, some in-person)
# 496      Hybrid (some remote, some in-person)
# 497      Hybrid (some remote, some in-person)
# 498                                    Remote
# 499                                    Remote
# 500                                    Remote
# 501                                    Remote
# 502                                    Remote
# 503                                    Remote
# 504      Hybrid (some remote, some in-person)
# 505                                    Remote
# 506                                    Remote
# 507      Hybrid (some remote, some in-person)
# 508                                    Remote
# 509      Hybrid (some remote, some in-person)
# 510                                    Remote
# 511                                 In-person
# 512                                    Remote
# 513                                    Remote
# 514                                    Remote
# 515                                    Remote
# 516      Hybrid (some remote, some in-person)
# 517                                    Remote
# 518                                 In-person
# 519      Hybrid (some remote, some in-person)
# 520      Hybrid (some remote, some in-person)
# 521      Hybrid (some remote, some in-person)
# 522                                    Remote
# 523      Hybrid (some remote, some in-person)
# 524      Hybrid (some remote, some in-person)
# 525                                    Remote
# 526      Hybrid (some remote, some in-person)
# 527      Hybrid (some remote, some in-person)
# 528                                 In-person
# 529                                 In-person
# 530      Hybrid (some remote, some in-person)
# 531                                    Remote
# 532                                    Remote
# 533      Hybrid (some remote, some in-person)
# 534                                    Remote
# 535      Hybrid (some remote, some in-person)
# 536                                    Remote
# 537                                    Remote
# 538                                    Remote
# 539      Hybrid (some remote, some in-person)
# 540      Hybrid (some remote, some in-person)
# 541      Hybrid (some remote, some in-person)
# 542                                 In-person
# 543                                 In-person
# 544      Hybrid (some remote, some in-person)
# 545                                    Remote
# 546      Hybrid (some remote, some in-person)
# 547      Hybrid (some remote, some in-person)
# 548                                    Remote
# 549                                    Remote
# 550                                 In-person
# 551                                    Remote
# 552                                    Remote
# 553                                    Remote
# 554                                    Remote
# 555                                    Remote
# 556      Hybrid (some remote, some in-person)
# 557                                    Remote
# 558      Hybrid (some remote, some in-person)
# 559      Hybrid (some remote, some in-person)
# 560      Hybrid (some remote, some in-person)
# 561                                 In-person
# 562      Hybrid (some remote, some in-person)
# 563      Hybrid (some remote, some in-person)
# 564      Hybrid (some remote, some in-person)
# 565                                    Remote
# 566                                    Remote
# 567                                    Remote
# 568                                    Remote
# 569                                    Remote
# 570                                    Remote
# 571                                    Remote
# 572                                    Remote
# 573      Hybrid (some remote, some in-person)
# 574                                 In-person
# 575      Hybrid (some remote, some in-person)
# 576                                    Remote
# 577                                    Remote
# 578      Hybrid (some remote, some in-person)
# 579      Hybrid (some remote, some in-person)
# 580                                 In-person
# 581                                    Remote
# 582                                 In-person
# 583                                    Remote
# 584      Hybrid (some remote, some in-person)
# 585                                    Remote
# 586                                    Remote
# 587                                    Remote
# 588      Hybrid (some remote, some in-person)
# 589                                    Remote
# 590      Hybrid (some remote, some in-person)
# 591                                    Remote
# 592      Hybrid (some remote, some in-person)
# 593      Hybrid (some remote, some in-person)
# 594                                 In-person
# 595                                    Remote
# 596      Hybrid (some remote, some in-person)
# 597      Hybrid (some remote, some in-person)
# 598                                    Remote
# 599                                    Remote
# 600                                 In-person
# 601                                    Remote
# 602                                    Remote
# 603      Hybrid (some remote, some in-person)
# 604      Hybrid (some remote, some in-person)
# 605      Hybrid (some remote, some in-person)
# 606                                    Remote
# 607      Hybrid (some remote, some in-person)
# 608                                    Remote
# 609      Hybrid (some remote, some in-person)
# 610                                    Remote
# 611                                 In-person
# 612                                    Remote
# 613                                    Remote
# 614      Hybrid (some remote, some in-person)
# 615      Hybrid (some remote, some in-person)
# 616                                    Remote
# 617                                 In-person
# 618                                    Remote
# 619                                    Remote
# 620      Hybrid (some remote, some in-person)
# 621      Hybrid (some remote, some in-person)
# 622                                    Remote
# 623      Hybrid (some remote, some in-person)
# 624                                    Remote
# 625      Hybrid (some remote, some in-person)
# 626      Hybrid (some remote, some in-person)
# 627                                    Remote
# 628                                    Remote
# 629                                    Remote
# 630                                    Remote
# 631      Hybrid (some remote, some in-person)
# 632      Hybrid (some remote, some in-person)
# 633      Hybrid (some remote, some in-person)
# 634      Hybrid (some remote, some in-person)
# 635      Hybrid (some remote, some in-person)
# 636                                    Remote
# 637      Hybrid (some remote, some in-person)
# 638      Hybrid (some remote, some in-person)
# 639      Hybrid (some remote, some in-person)
# 640      Hybrid (some remote, some in-person)
# 641      Hybrid (some remote, some in-person)
# 642                                    Remote
# 643      Hybrid (some remote, some in-person)
# 644                                    Remote
# 645      Hybrid (some remote, some in-person)
# 646      Hybrid (some remote, some in-person)
# 647      Hybrid (some remote, some in-person)
# 648      Hybrid (some remote, some in-person)
# 649      Hybrid (some remote, some in-person)
# 650                                    Remote
# 651                                    Remote
# 652                                    Remote
# 653                                    Remote
# 654                                 In-person
# 655                                 In-person
# 656      Hybrid (some remote, some in-person)
# 657                                    Remote
# 658      Hybrid (some remote, some in-person)
# 659                                 In-person
# 660      Hybrid (some remote, some in-person)
# 661      Hybrid (some remote, some in-person)
# 662                                    Remote
# 663                                    Remote
# 664                                 In-person
# 665                                    Remote
# 666      Hybrid (some remote, some in-person)
# 667                                 In-person
# 668      Hybrid (some remote, some in-person)
# 669      Hybrid (some remote, some in-person)
# 670                                 In-person
# 671      Hybrid (some remote, some in-person)
# 672      Hybrid (some remote, some in-person)
# 673                                    Remote
# 674      Hybrid (some remote, some in-person)
# 675      Hybrid (some remote, some in-person)
# 676      Hybrid (some remote, some in-person)
# 677                                    Remote
# 678                                 In-person
# 679      Hybrid (some remote, some in-person)
# 680      Hybrid (some remote, some in-person)
# 681      Hybrid (some remote, some in-person)
# 682                                    Remote
# 683                                    Remote
# 684                                 In-person
# 685      Hybrid (some remote, some in-person)
# 686                                    Remote
# 687                                 In-person
# 688      Hybrid (some remote, some in-person)
# 689                                    Remote
# 690                                    Remote
# 691      Hybrid (some remote, some in-person)
# 692      Hybrid (some remote, some in-person)
# 693                                 In-person
# 694      Hybrid (some remote, some in-person)
# 695                                    Remote
# 696                                    Remote
# 697                                 In-person
# 698                                    Remote
# 699                                    Remote
# 700                                    Remote
# 701      Hybrid (some remote, some in-person)
# 702                                    Remote
# 703                                    Remote
# 704                                    Remote
# 705                                    Remote
# 706                                    Remote
# 707                                 In-person
# 708                                    Remote
# 709                                    Remote
# 710      Hybrid (some remote, some in-person)
# 711                                 In-person
# 712                                    Remote
# 713                                 In-person
# 714                                    Remote
# 715      Hybrid (some remote, some in-person)
# 716      Hybrid (some remote, some in-person)
# 717      Hybrid (some remote, some in-person)
# 718                                    Remote
# 719      Hybrid (some remote, some in-person)
# 720      Hybrid (some remote, some in-person)
# 721      Hybrid (some remote, some in-person)
# 722      Hybrid (some remote, some in-person)
# 723                                    Remote
# 724                                 In-person
# 725                                    Remote
# 726                                    Remote
# 727      Hybrid (some remote, some in-person)
# 728                                 In-person
# 729                                    Remote
# 730                                    Remote
# 731                                    Remote
# 732                                    Remote
# 733                                 In-person
# 734      Hybrid (some remote, some in-person)
# 735                                 In-person
# 736      Hybrid (some remote, some in-person)
# 737                                    Remote
# 738      Hybrid (some remote, some in-person)
# 739      Hybrid (some remote, some in-person)
# 740      Hybrid (some remote, some in-person)
# 741                                    Remote
# 742      Hybrid (some remote, some in-person)
# 743                                    Remote
# 744      Hybrid (some remote, some in-person)
# 745                                    Remote
# 746                                    Remote
# 747      Hybrid (some remote, some in-person)
# 748                                    Remote
# 749      Hybrid (some remote, some in-person)
# 750      Hybrid (some remote, some in-person)
# 751      Hybrid (some remote, some in-person)
# 752                                    Remote
# 753                                    Remote
# 754                                    Remote
# 755                                    Remote
# 756      Hybrid (some remote, some in-person)
# 757      Hybrid (some remote, some in-person)
# 758      Hybrid (some remote, some in-person)
# 759                                    Remote
# 760      Hybrid (some remote, some in-person)
# 761                                    Remote
# 762                                 In-person
# 763      Hybrid (some remote, some in-person)
# 764                                 In-person
# 765                                    Remote
# 766                                    Remote
# 767      Hybrid (some remote, some in-person)
# 768                                    Remote
# 769                                    Remote
# 770                                 In-person
# 771      Hybrid (some remote, some in-person)
# 772                                    Remote
# 773      Hybrid (some remote, some in-person)
# 774      Hybrid (some remote, some in-person)
# 775      Hybrid (some remote, some in-person)
# 776                                    Remote
# 777      Hybrid (some remote, some in-person)
# 778                                    Remote
# 779      Hybrid (some remote, some in-person)
# 780      Hybrid (some remote, some in-person)
# 781      Hybrid (some remote, some in-person)
# 782      Hybrid (some remote, some in-person)
# 783      Hybrid (some remote, some in-person)
# 784                                    Remote
# 785      Hybrid (some remote, some in-person)
# 786      Hybrid (some remote, some in-person)
# 787                                    Remote
# 788      Hybrid (some remote, some in-person)
# 789                                    Remote
# 790                                    Remote
# 791      Hybrid (some remote, some in-person)
# 792                                 In-person
# 793      Hybrid (some remote, some in-person)
# 794                                    Remote
# 795                                    Remote
# 796                                    Remote
# 797                                    Remote
# 798      Hybrid (some remote, some in-person)
# 799      Hybrid (some remote, some in-person)
# 800      Hybrid (some remote, some in-person)
# 801                                    Remote
# 802                                 In-person
# 803      Hybrid (some remote, some in-person)
# 804                                 In-person
# 805      Hybrid (some remote, some in-person)
# 806      Hybrid (some remote, some in-person)
# 807                                 In-person
# 808                                    Remote
# 809                                    Remote
# 810                                 In-person
# 811      Hybrid (some remote, some in-person)
# 812      Hybrid (some remote, some in-person)
# 813                                    Remote
# 814      Hybrid (some remote, some in-person)
# 815                                 In-person
# 816                                    Remote
# 817                                 In-person
# 818                                 In-person
# 819                                 In-person
# 820      Hybrid (some remote, some in-person)
# 821                                    Remote
# 822      Hybrid (some remote, some in-person)
# 823                                    Remote
# 824                                    Remote
# 825                                 In-person
# 826                                    Remote
# 827      Hybrid (some remote, some in-person)
# 828      Hybrid (some remote, some in-person)
# 829                                    Remote
# 830      Hybrid (some remote, some in-person)
# 831                                    Remote
# 832      Hybrid (some remote, some in-person)
# 833      Hybrid (some remote, some in-person)
# 834                                 In-person
# 835                                    Remote
# 836      Hybrid (some remote, some in-person)
# 837      Hybrid (some remote, some in-person)
# 838      Hybrid (some remote, some in-person)
# 839      Hybrid (some remote, some in-person)
# 840      Hybrid (some remote, some in-person)
# 841      Hybrid (some remote, some in-person)
# 842                                    Remote
# 843                                    Remote
# 844      Hybrid (some remote, some in-person)
# 845                                    Remote
# 846      Hybrid (some remote, some in-person)
# 847      Hybrid (some remote, some in-person)
# 848                                    Remote
# 849                                    Remote
# 850      Hybrid (some remote, some in-person)
# 851                                    Remote
# 852                                    Remote
# 853      Hybrid (some remote, some in-person)
# 854      Hybrid (some remote, some in-person)
# 855                                    Remote
# 856      Hybrid (some remote, some in-person)
# 857      Hybrid (some remote, some in-person)
# 858                                    Remote
# 859      Hybrid (some remote, some in-person)
# 860                                    Remote
# 861                                    Remote
# 862                                    Remote
# 863      Hybrid (some remote, some in-person)
# 864      Hybrid (some remote, some in-person)
# 865      Hybrid (some remote, some in-person)
# 866      Hybrid (some remote, some in-person)
# 867      Hybrid (some remote, some in-person)
# 868      Hybrid (some remote, some in-person)
# 869                                    Remote
# 870      Hybrid (some remote, some in-person)
# 871                                    Remote
# 872                                 In-person
# 873      Hybrid (some remote, some in-person)
# 874      Hybrid (some remote, some in-person)
# 875      Hybrid (some remote, some in-person)
# 876      Hybrid (some remote, some in-person)
# 877                                    Remote
# 878      Hybrid (some remote, some in-person)
# 879      Hybrid (some remote, some in-person)
# 880      Hybrid (some remote, some in-person)
# 881      Hybrid (some remote, some in-person)
# 882      Hybrid (some remote, some in-person)
# 883                                    Remote
# 884      Hybrid (some remote, some in-person)
# 885                                    Remote
# 886                                    Remote
# 887      Hybrid (some remote, some in-person)
# 888      Hybrid (some remote, some in-person)
# 889                                    Remote
# 890      Hybrid (some remote, some in-person)
# 891      Hybrid (some remote, some in-person)
# 892                                 In-person
# 893                                    Remote
# 894                                    Remote
# 895      Hybrid (some remote, some in-person)
# 896                                 In-person
# 897                                 In-person
# 898                                 In-person
# 899                                    Remote
# 900                                    Remote
# 901      Hybrid (some remote, some in-person)
# 902                                    Remote
# 903      Hybrid (some remote, some in-person)
# 904      Hybrid (some remote, some in-person)
# 905      Hybrid (some remote, some in-person)
# 906                                    Remote
# 907      Hybrid (some remote, some in-person)
# 908                                    Remote
# 909      Hybrid (some remote, some in-person)
# 910                                 In-person
# 911                                 In-person
# 912                                 In-person
# 913                                    Remote
# 914      Hybrid (some remote, some in-person)
# 915                                    Remote
# 916      Hybrid (some remote, some in-person)
# 917                                    Remote
# 918                                    Remote
# 919      Hybrid (some remote, some in-person)
# 920                                 In-person
# 921      Hybrid (some remote, some in-person)
# 922      Hybrid (some remote, some in-person)
# 923                                    Remote
# 924      Hybrid (some remote, some in-person)
# 925      Hybrid (some remote, some in-person)
# 926      Hybrid (some remote, some in-person)
# 927      Hybrid (some remote, some in-person)
# 928      Hybrid (some remote, some in-person)
# 929      Hybrid (some remote, some in-person)
# 930      Hybrid (some remote, some in-person)
# 931                                    Remote
# 932                                    Remote
# 933                                    Remote
# 934                                    Remote
# 935      Hybrid (some remote, some in-person)
# 936      Hybrid (some remote, some in-person)
# 937                                    Remote
# 938                                    Remote
# 939                                 In-person
# 940      Hybrid (some remote, some in-person)
# 941                                 In-person
# 942      Hybrid (some remote, some in-person)
# 943      Hybrid (some remote, some in-person)
# 944                                    Remote
# 945      Hybrid (some remote, some in-person)
# 946      Hybrid (some remote, some in-person)
# 947                                 In-person
# 948      Hybrid (some remote, some in-person)
# 949                                 In-person
# 950                                 In-person
# 951      Hybrid (some remote, some in-person)
# 952                                    Remote
# 953      Hybrid (some remote, some in-person)
# 954      Hybrid (some remote, some in-person)
# 955      Hybrid (some remote, some in-person)
# 956      Hybrid (some remote, some in-person)
# 957      Hybrid (some remote, some in-person)
# 958      Hybrid (some remote, some in-person)
# 959                                 In-person
# 960                                    Remote
# 961      Hybrid (some remote, some in-person)
# 962      Hybrid (some remote, some in-person)
# 963      Hybrid (some remote, some in-person)
# 964      Hybrid (some remote, some in-person)
# 965      Hybrid (some remote, some in-person)
# 966                                    Remote
# 967      Hybrid (some remote, some in-person)
# 968      Hybrid (some remote, some in-person)
# 969                                    Remote
# 970      Hybrid (some remote, some in-person)
# 971      Hybrid (some remote, some in-person)
# 972      Hybrid (some remote, some in-person)
# 973      Hybrid (some remote, some in-person)
# 974      Hybrid (some remote, some in-person)
# 975      Hybrid (some remote, some in-person)
# 976                                    Remote
# 977                                    Remote
# 978      Hybrid (some remote, some in-person)
# 979      Hybrid (some remote, some in-person)
# 980      Hybrid (some remote, some in-person)
# 981                                    Remote
# 982      Hybrid (some remote, some in-person)
# 983      Hybrid (some remote, some in-person)
# 984      Hybrid (some remote, some in-person)
# 985                                    Remote
# 986                                    Remote
# 987                                    Remote
# 988                                    Remote
# 989      Hybrid (some remote, some in-person)
# 990                                    Remote
# 991      Hybrid (some remote, some in-person)
# 992      Hybrid (some remote, some in-person)
# 993                                    Remote
# 994      Hybrid (some remote, some in-person)
# 995      Hybrid (some remote, some in-person)
# 996                                    Remote
# 997                                    Remote
# 998      Hybrid (some remote, some in-person)
# 999      Hybrid (some remote, some in-person)
# 1000                                In-person
# 1001     Hybrid (some remote, some in-person)
# 1002                                   Remote
# 1003                                   Remote
# 1004                                   Remote
# 1005                                In-person
# 1006     Hybrid (some remote, some in-person)
# 1007                                   Remote
# 1008                                   Remote
# 1009     Hybrid (some remote, some in-person)
# 1010                                   Remote
# 1011     Hybrid (some remote, some in-person)
# 1012     Hybrid (some remote, some in-person)
# 1013     Hybrid (some remote, some in-person)
# 1014     Hybrid (some remote, some in-person)
# 1015                                In-person
# 1016                                   Remote
# 1017     Hybrid (some remote, some in-person)
# 1018                                   Remote
# 1019                                   Remote
# 1020                                   Remote
# 1021     Hybrid (some remote, some in-person)
# 1022     Hybrid (some remote, some in-person)
# 1023                                   Remote
# 1024                                   Remote
# 1025                                   Remote
# 1026     Hybrid (some remote, some in-person)
# 1027                                   Remote
# 1028                                   Remote
# 1029                                   Remote
# 1030     Hybrid (some remote, some in-person)
# 1031     Hybrid (some remote, some in-person)
# 1032                                   Remote
# 1033                                   Remote
# 1034     Hybrid (some remote, some in-person)
# 1035                                In-person
# 1036                                   Remote
# 1037                                   Remote
# 1038                                   Remote
# 1039                                   Remote
# 1040     Hybrid (some remote, some in-person)
# 1041     Hybrid (some remote, some in-person)
# 1042     Hybrid (some remote, some in-person)
# ...
# 65090    Hybrid (some remote, some in-person)
# 65091    Hybrid (some remote, some in-person)
# 65092    Hybrid (some remote, some in-person)
# 65093                                  Remote
# 65094    Hybrid (some remote, some in-person)
# 65095    Hybrid (some remote, some in-person)
# 65096                               In-person
# 65097    Hybrid (some remote, some in-person)
# 65098    Hybrid (some remote, some in-person)
# 65099    Hybrid (some remote, some in-person)
# 65100                                  Remote
# 65101    Hybrid (some remote, some in-person)
# 65102                               In-person
# 65103    Hybrid (some remote, some in-person)
# 65104                                  Remote
# 65105    Hybrid (some remote, some in-person)
# 65106    Hybrid (some remote, some in-person)
# 65107    Hybrid (some remote, some in-person)
# 65108    Hybrid (some remote, some in-person)
# 65109    Hybrid (some remote, some in-person)
# 65110    Hybrid (some remote, some in-person)
# 65111                               In-person
# 65112    Hybrid (some remote, some in-person)
# 65113                                  Remote
# 65114                                  Remote
# 65115                               In-person
# 65116    Hybrid (some remote, some in-person)
# 65117                               In-person
# 65118                                  Remote
# 65119    Hybrid (some remote, some in-person)
# 65120                               In-person
# 65121                                  Remote
# 65122                               In-person
# 65123    Hybrid (some remote, some in-person)
# 65124                               In-person
# 65125    Hybrid (some remote, some in-person)
# 65126    Hybrid (some remote, some in-person)
# 65127                                  Remote
# 65128    Hybrid (some remote, some in-person)
# 65129    Hybrid (some remote, some in-person)
# 65130    Hybrid (some remote, some in-person)
# 65131    Hybrid (some remote, some in-person)
# 65132                                  Remote
# 65133                                  Remote
# 65134    Hybrid (some remote, some in-person)
# 65135    Hybrid (some remote, some in-person)
# 65136                               In-person
# 65137                               In-person
# 65138                               In-person
# 65139                               In-person
# 65140                               In-person
# 65141    Hybrid (some remote, some in-person)
# 65142    Hybrid (some remote, some in-person)
# 65143    Hybrid (some remote, some in-person)
# 65144    Hybrid (some remote, some in-person)
# 65145                               In-person
# 65146    Hybrid (some remote, some in-person)
# 65147    Hybrid (some remote, some in-person)
# 65148    Hybrid (some remote, some in-person)
# 65149    Hybrid (some remote, some in-person)
# 65150                                  Remote
# 65151    Hybrid (some remote, some in-person)
# 65152    Hybrid (some remote, some in-person)
# 65153                               In-person
# 65154    Hybrid (some remote, some in-person)
# 65155                               In-person
# 65156                               In-person
# 65157    Hybrid (some remote, some in-person)
# 65158    Hybrid (some remote, some in-person)
# 65159                                  Remote
# 65160                                  Remote
# 65161    Hybrid (some remote, some in-person)
# 65162                               In-person
# 65163    Hybrid (some remote, some in-person)
# 65164                               In-person
# 65165                                  Remote
# 65166                                  Remote
# 65167                               In-person
# 65168                               In-person
# 65169                                  Remote
# 65170    Hybrid (some remote, some in-person)
# 65171                                  Remote
# 65172    Hybrid (some remote, some in-person)
# 65173    Hybrid (some remote, some in-person)
# 65174    Hybrid (some remote, some in-person)
# 65175                                  Remote
# 65176    Hybrid (some remote, some in-person)
# 65177    Hybrid (some remote, some in-person)
# 65178    Hybrid (some remote, some in-person)
# 65179                                  Remote
# 65180    Hybrid (some remote, some in-person)
# 65181    Hybrid (some remote, some in-person)
# 65182    Hybrid (some remote, some in-person)
# 65183                               In-person
# 65184                                  Remote
# 65185    Hybrid (some remote, some in-person)
# 65186    Hybrid (some remote, some in-person)
# 65187    Hybrid (some remote, some in-person)
# 65188    Hybrid (some remote, some in-person)
# 65189                                  Remote
# 65190    Hybrid (some remote, some in-person)
# 65191                               In-person
# 65192                                  Remote
# 65193    Hybrid (some remote, some in-person)
# 65194                                  Remote
# 65195                               In-person
# 65196    Hybrid (some remote, some in-person)
# 65197                                  Remote
# 65198                               In-person
# 65199    Hybrid (some remote, some in-person)
# 65200                               In-person
# 65201                                  Remote
# 65202    Hybrid (some remote, some in-person)
# 65203                               In-person
# 65204                               In-person
# 65205    Hybrid (some remote, some in-person)
# 65206                                  Remote
# 65207                                  Remote
# 65208    Hybrid (some remote, some in-person)
# 65209    Hybrid (some remote, some in-person)
# 65210                               In-person
# 65211    Hybrid (some remote, some in-person)
# 65212                               In-person
# 65213                                  Remote
# 65214                                  Remote
# 65215                               In-person
# 65216    Hybrid (some remote, some in-person)
# 65217    Hybrid (some remote, some in-person)
# 65218                                  Remote
# 65219                                  Remote
# 65220                                  Remote
# 65221    Hybrid (some remote, some in-person)
# 65222    Hybrid (some remote, some in-person)
# 65223                               In-person
# 65224                                  Remote
# 65225    Hybrid (some remote, some in-person)
# 65226                                  Remote
# 65227    Hybrid (some remote, some in-person)
# 65228    Hybrid (some remote, some in-person)
# 65229    Hybrid (some remote, some in-person)
# 65230    Hybrid (some remote, some in-person)
# 65231    Hybrid (some remote, some in-person)
# 65232    Hybrid (some remote, some in-person)
# 65233    Hybrid (some remote, some in-person)
# 65234                                  Remote
# 65235    Hybrid (some remote, some in-person)
# 65236    Hybrid (some remote, some in-person)
# 65237                               In-person
# 65238    Hybrid (some remote, some in-person)
# 65239                                  Remote
# 65240                                  Remote
# 65241    Hybrid (some remote, some in-person)
# 65242                                  Remote
# 65243    Hybrid (some remote, some in-person)
# 65244                                  Remote
# 65245    Hybrid (some remote, some in-person)
# 65246                                  Remote
# 65247                                  Remote
# 65248                               In-person
# 65249                                  Remote
# 65250                                  Remote
# 65251    Hybrid (some remote, some in-person)
# 65252                                  Remote
# 65253                                  Remote
# 65254    Hybrid (some remote, some in-person)
# 65255                                  Remote
# 65256                                  Remote
# 65257    Hybrid (some remote, some in-person)
# 65258                                  Remote
# 65259                                  Remote
# 65260    Hybrid (some remote, some in-person)
# 65261    Hybrid (some remote, some in-person)
# 65262    Hybrid (some remote, some in-person)
# 65263    Hybrid (some remote, some in-person)
# 65264                                  Remote
# 65265                               In-person
# 65266                               In-person
# 65267                               In-person
# 65268                                  Remote
# 65269                                  Remote
# 65270                                  Remote
# 65271    Hybrid (some remote, some in-person)
# 65272                                  Remote
# 65273                                  Remote
# 65274    Hybrid (some remote, some in-person)
# 65275                               In-person
# 65276    Hybrid (some remote, some in-person)
# 65277    Hybrid (some remote, some in-person)
# 65278                                  Remote
# 65279    Hybrid (some remote, some in-person)
# 65280    Hybrid (some remote, some in-person)
# 65281                                  Remote
# 65282    Hybrid (some remote, some in-person)
# 65283                                  Remote
# 65284    Hybrid (some remote, some in-person)
# 65285    Hybrid (some remote, some in-person)
# 65286                               In-person
# 65287    Hybrid (some remote, some in-person)
# 65288                                  Remote
# 65289                                  Remote
# 65290    Hybrid (some remote, some in-person)
# 65291                               In-person
# 65292    Hybrid (some remote, some in-person)
# 65293    Hybrid (some remote, some in-person)
# 65294    Hybrid (some remote, some in-person)
# 65295    Hybrid (some remote, some in-person)
# 65296                                  Remote
# 65297    Hybrid (some remote, some in-person)
# 65298    Hybrid (some remote, some in-person)
# 65299    Hybrid (some remote, some in-person)
# 65300    Hybrid (some remote, some in-person)
# 65301    Hybrid (some remote, some in-person)
# 65302    Hybrid (some remote, some in-person)
# 65303                                  Remote
# 65304    Hybrid (some remote, some in-person)
# 65305    Hybrid (some remote, some in-person)
# 65306    Hybrid (some remote, some in-person)
# 65307                               In-person
# 65308                               In-person
# 65309    Hybrid (some remote, some in-person)
# 65310    Hybrid (some remote, some in-person)
# 65311                                  Remote
# 65312    Hybrid (some remote, some in-person)
# 65313                               In-person
# 65314    Hybrid (some remote, some in-person)
# 65315                                  Remote
# 65316    Hybrid (some remote, some in-person)
# 65317    Hybrid (some remote, some in-person)
# 65318    Hybrid (some remote, some in-person)
# 65319                               In-person
# 65320    Hybrid (some remote, some in-person)
# 65321                               In-person
# 65322    Hybrid (some remote, some in-person)
# 65323                                  Remote
# 65324    Hybrid (some remote, some in-person)
# 65325    Hybrid (some remote, some in-person)
# 65326    Hybrid (some remote, some in-person)
# 65327    Hybrid (some remote, some in-person)
# 65328    Hybrid (some remote, some in-person)
# 65329                               In-person
# 65330    Hybrid (some remote, some in-person)
# 65331                                  Remote
# 65332                               In-person
# 65333    Hybrid (some remote, some in-person)
# 65334    Hybrid (some remote, some in-person)
# 65335                               In-person
# 65336    Hybrid (some remote, some in-person)
# 65337    Hybrid (some remote, some in-person)
# 65338    Hybrid (some remote, some in-person)
# 65339    Hybrid (some remote, some in-person)
# 65340                               In-person
# 65341    Hybrid (some remote, some in-person)
# 65342                                  Remote
# 65343                               In-person
# 65344                               In-person
# 65345    Hybrid (some remote, some in-person)
# 65346                                  Remote
# 65347    Hybrid (some remote, some in-person)
# 65348                                  Remote
# 65349    Hybrid (some remote, some in-person)
# 65350    Hybrid (some remote, some in-person)
# 65351    Hybrid (some remote, some in-person)
# 65352    Hybrid (some remote, some in-person)
# 65353    Hybrid (some remote, some in-person)
# 65354                               In-person
# 65355                               In-person
# 65356    Hybrid (some remote, some in-person)
# 65357    Hybrid (some remote, some in-person)
# 65358                                  Remote
# 65359                               In-person
# 65360    Hybrid (some remote, some in-person)
# 65361                                  Remote
# 65362                                  Remote
# 65363                                  Remote
# 65364    Hybrid (some remote, some in-person)
# 65365                               In-person
# 65366                                  Remote
# 65367                                  Remote
# 65368                                  Remote
# 65369    Hybrid (some remote, some in-person)
# 65370    Hybrid (some remote, some in-person)
# 65371    Hybrid (some remote, some in-person)
# 65372                               In-person
# 65373                                  Remote
# 65374                                  Remote
# 65375    Hybrid (some remote, some in-person)
# 65376                                  Remote
# 65377    Hybrid (some remote, some in-person)
# 65378    Hybrid (some remote, some in-person)
# 65379    Hybrid (some remote, some in-person)
# 65380    Hybrid (some remote, some in-person)
# 65381    Hybrid (some remote, some in-person)
# 65382    Hybrid (some remote, some in-person)
# 65383    Hybrid (some remote, some in-person)
# 65384    Hybrid (some remote, some in-person)
# 65385                                  Remote
# 65386    Hybrid (some remote, some in-person)
# 65387    Hybrid (some remote, some in-person)
# 65388    Hybrid (some remote, some in-person)
# 65389    Hybrid (some remote, some in-person)
# 65390                               In-person
# 65391    Hybrid (some remote, some in-person)
# 65392    Hybrid (some remote, some in-person)
# 65393    Hybrid (some remote, some in-person)
# 65394    Hybrid (some remote, some in-person)
# 65395    Hybrid (some remote, some in-person)
# 65396    Hybrid (some remote, some in-person)
# 65397    Hybrid (some remote, some in-person)
# 65398    Hybrid (some remote, some in-person)
# 65399                               In-person
# 65400    Hybrid (some remote, some in-person)
# 65401    Hybrid (some remote, some in-person)
# 65402                                  Remote
# 65403    Hybrid (some remote, some in-person)
# 65404    Hybrid (some remote, some in-person)
# 65405    Hybrid (some remote, some in-person)
# 65406                                  Remote
# 65407    Hybrid (some remote, some in-person)
# 65408    Hybrid (some remote, some in-person)
# 65409                                  Remote
# 65410    Hybrid (some remote, some in-person)
# 65411                                  Remote
# 65412                                  Remote
# 65413    Hybrid (some remote, some in-person)
# 65414                               In-person
# 65415    Hybrid (some remote, some in-person)
# 65416    Hybrid (some remote, some in-person)
# 65417    Hybrid (some remote, some in-person)
# 65418    Hybrid (some remote, some in-person)
# 65419    Hybrid (some remote, some in-person)
# 65420    Hybrid (some remote, some in-person)
# 65421                                  Remote
# 65422    Hybrid (some remote, some in-person)
# 65423    Hybrid (some remote, some in-person)
# 65424                                  Remote
# 65425    Hybrid (some remote, some in-person)
# 65426    Hybrid (some remote, some in-person)
# 65427                               In-person
# 65428                                  Remote
# 65429    Hybrid (some remote, some in-person)
# 65430                               In-person
# 65431    Hybrid (some remote, some in-person)
# 65432                                  Remote
# 65433                                  Remote
# 65434                               In-person
# 65435    Hybrid (some remote, some in-person)
# 65436    Hybrid (some remote, some in-person)

# %% [markdown]
# ##### Task 8: Check for any compensation-related columns and describe their distribution.

# %%
Remote_Work_counts = df["RemoteWork"].value_counts()
plt.figure(figsize=(8, 6))
Remote_Work.plot(kind='bar')
plt.title('Duplicate Distribution by Remote Work')
plt.xlabel('Remote Work')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 Remote_Work_counts = df["RemoteWork"].value_counts()
# ----> 2 plt.figure(figsize=(8, 6))
#       3 Remote_Work.plot(kind='bar')
#       4 plt.title('Duplicate Distribution by Remote Work')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### Summary

# %% [markdown]
# **In this lab, you focused on imputing missing values in the dataset.**
#
# - Use the <code>pandas.read_csv()</code> function to load a dataset from a CSV file into a DataFrame.
#
# - Download the dataset if it's not available online and specify the correct file path.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11-05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-29|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-27|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-26|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
