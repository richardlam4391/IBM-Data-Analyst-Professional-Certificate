# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Histogram**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# In this lab, you will focus on the visualization of data. The dataset will be provided through an RDBMS, and you will need to use SQL queries to extract the required data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# - Visualize the distribution of data using histograms.
#
# - Visualize relationships between features.
#
# - Explore data composition and comparisons.

# %% [markdown]
# ## Demo: Working with database

# %% [markdown]
# #### Download the database file.

# %%
# !wget -O survey-data.sqlite https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/QR9YeprUYhOoLafzlLspAw/survey-results-public.sqlite
# Out:
# --2026-06-21 14:23:20--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/QR9YeprUYhOoLafzlLspAw/survey-results-public.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# 200 OKequest sent, awaiting response...
# Length: 211415040 (202M) [application/octet-stream]
# Saving to: ‘survey-data.sqlite’
#
# survey-data.sqlite  100%[===================>] 201.62M  40.7MB/s    in 4.9s
#
# 2026-06-21 14:23:26 (40.8 MB/s) - ‘survey-data.sqlite’ saved [211415040/211415040]

# %% [markdown]
# #### Install the required libraries and import them

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
# !pip install seaborn

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Connect to the SQLite database

# %%
conn = sqlite3.connect('survey-data.sqlite')

# %% [markdown]
# ## Demo: Basic SQL queries
#
# **Demo 1: Count the number of rows in the table**

# %%
QUERY = "SELECT COUNT(*) FROM main"
df = pd.read_sql_query(QUERY, conn)
print(df)
# Out:
#    COUNT(*)
# 0     65437

# %% [markdown]
# **Demo 2: List all tables**

# %%
QUERY = """
SELECT name as Table_Name 
FROM sqlite_master 
WHERE type = 'table'
"""
pd.read_sql_query(QUERY, conn)
# Out:
#   Table_Name
# 0       main

# %% [markdown]
# **Demo 3: Group data by age**

# %%
QUERY = """
SELECT Age, COUNT(*) as count 
FROM main 
GROUP BY Age 
ORDER BY Age
"""
df_age = pd.read_sql_query(QUERY, conn)
print(df_age)
# Out:
#                   Age  count
# 0     18-24 years old  14098
# 1     25-34 years old  23911
# 2     35-44 years old  14942
# 3     45-54 years old   6249
# 4     55-64 years old   2575
# 5   65 years or older    772
# 6   Prefer not to say    322
# 7  Under 18 years old   2568

# %% [markdown]
# ## Hands-on Lab: Visualizing Data with Histograms

# %% [markdown]
# ### 1. Visualizing the distribution of data (Histograms)

# %% [markdown]
# **1.1 Histogram of `CompTotal` (Total Compensation)**

# %% [markdown]
# Objective: Plot a histogram of `CompTotal` to visualize the distribution of respondents' total compensation.

# %%
## Write your code here
QUERY1 = """
SELECT CompTotal 
FROM main 
WHERE CompTotal IS NOT NULL 
AND CompTotal > 0
"""
df1 = pd.read_sql_query(QUERY1, conn)
quantile_95 = df1['CompTotal'].quantile(0.95)
df_filtered = df1[df1['CompTotal'] <= quantile_95]
plt.figure(figsize=(10, 6))
sns.histplot(data=df_filtered, x='CompTotal', bins=15, color='blue')
plt.title('Histogram of Total Compensation')
plt.xlabel('Total Compensation')
plt.ylabel('Respondent Count')
plt.show()

# %% [markdown]
# **1.2 Histogram of YearsCodePro (Years of Professional Coding Experience)**

# %% [markdown]
# Objective: Plot a histogram of `YearsCodePro` to analyze the distribution of coding experience among respondents.

# %%
## Write your code here
QUERY2= """
SELECT YearsCodePro 
FROM main
WHERE YearsCodePro IS NOT NULL"""
df2 = pd.read_sql_query(QUERY2, conn)
plt.figure(figsize=(10, 5))
sns.histplot(df2['YearsCodePro'], bins=20, kde=False, color='skyblue')
plt.title('Distribution of Professional Coding Experience')
plt.xlabel('Years of Professional Coding')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 2. Visualizing Relationships in Data

# %% [markdown]
# **2.1 Histogram Comparison of `CompTotal` by `Age` Group**

# %% [markdown]
# Objective: Use histograms to compare the distribution of CompTotal across different Age groups.

# %%
## Write your code here
QUERY3 = """
SELECT CompTotal, Age 
FROM main
WHERE CompTotal IS NOT NULL 
AND Age IS NOT NULL 
AND CompTotal > 0
"""
df3 = pd.read_sql_query(QUERY3, conn)
q_limit = df3['CompTotal'].quantile(0.95)
df_cleaned = df3[df3['CompTotal'] <= q_limit]
plt.figure(figsize=(12, 6))
ax = sns.histplot(
    data=df_cleaned,
    x='CompTotal',
    hue='Age',
    multiple='stack',
    bins=25,
    palette='deep'
)
plt.title('Distribution of Compensation across different Age Groups')
plt.xlabel('Total Compensation (CompTotal)')
plt.ylabel('User Count')
sns.move_legend(ax, "upper right", frameon=True, title="Age Groups")
plt.tight_layout()

# %% [markdown]
# **2.2 Histogram of TimeSearching for Different Age Groups**

# %% [markdown]
# Objective: Use histograms to explore the distribution of `TimeSearching` (time spent searching for information) for respondents across different age groups.

# %%
## Write your code here
QUERY4 = """
SELECT TimeSearching, Age 
FROM main
WHERE TimeSearching IS NOT NULL AND Age IS NOT NULL
"""
df4 = pd.read_sql_query(QUERY4, conn)
g = sns.FacetGrid(df4, col="Age", sharey=False, height=4, aspect=1.2)
g.map(sns.histplot, "TimeSearching", bins=15)
g.set_titles("{col_name}")
plt.show()

# %% [markdown]
# ### 3. Visualizing the Composition of Data

# %% [markdown]
# **3.1 Histogram of Most Desired Databases (`DatabaseWantToWorkWith`)**

# %% [markdown]
# Objective: Visualize the most desired databases for future learning using a histogram of the top 5 databases.

# %%
## Write your code here
QUERY5 = """
SELECT DatabaseWantToWorkWith 
FROM main
WHERE DatabaseWantToWorkWith IS NOT NULL
"""
df5 = pd.read_sql_query(QUERY5, conn)
df_databases5 = df5['DatabaseWantToWorkWith'].str.split(';').explode()
plt.figure(figsize=(12, 6))
sns.countplot(y=df_databases5, order=df_databases5.value_counts().index, palette='viridis')
plt.title('Most Desired Databases')
plt.xlabel('Count')
plt.ylabel('Database')
plt.show()
# Out:
# /tmp/ipykernel_1713/3173233591.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df_databases5, order=df_databases5.value_counts().index, palette='viridis')

# %% [markdown]
# **3.2 Histogram of Preferred Work Locations (`RemoteWork`)**

# %% [markdown]
# Objective: Use a histogram to explore the distribution of preferred work arrangements (`remote work`).

# %%
## Write your code here
QUERY6 = """
SELECT RemoteWork 
FROM main 
WHERE RemoteWork IS NOT NULL
"""
df6 = pd.read_sql_query(QUERY6, conn)
plt.figure(figsize=(8, 4))
sns.histplot(data=df6, x='RemoteWork', shrink=0.8, color='teal')
plt.title('Preferred Work Locations')
plt.xticks(rotation=15)
plt.xlabel('Work Environment')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### 4. Visualizing Comparison of Data

# %% [markdown]
# **4.1 Histogram of Median CompTotal for Ages 45 to 60**

# %% [markdown]
# Objective: Plot the histogram for `CompTotal` within the age group 45 to 60 to analyze compensation distribution among mid-career respondents.

# %%
## Write your code here
QUERY7 = """
SELECT CompTotal 
FROM main
WHERE Age BETWEEN 45 AND 60 
  AND CompTotal IS NOT NULL 
  AND CompTotal < 500000;
"""
df7 = pd.read_sql_query(QUERY7, conn)
plt.figure(figsize=(10, 5))
sns.histplot(df7['CompTotal'], bins=25, color='orange')
plt.title('Compensation Distribution for Ages 45-60')
plt.xlabel('Total Compensation')
plt.ylabel('Count')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_1713/1746104215.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# **4.2 Histogram of Job Satisfaction (`JobSat`) by YearsCodePro**

# %% [markdown]
# Objective: Plot the histogram for `JobSat` scores based on respondents' years of professional coding experience.

# %%
## Write your code here
QUERY8 = """
SELECT JobSat, YearsCodePro 
FROM main 
WHERE JobSat IS NOT NULL AND YearsCodePro IS NOT NULL;
"""
df8 = pd.read_sql_query(QUERY8, conn)
plt.figure(figsize=(12, 6))
sns.histplot(data=df8, x='YearsCodePro', hue='JobSat', multiple='stack', bins=20, palette='magma')
plt.title('Job Satisfaction Distribution by Years of Professional Coding')
plt.xlabel('Years of Professional Coding')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Final step: Close the database connection

# %% [markdown]
# Once you've completed the lab, make sure to close the connection to the SQLite database:

# %%
conn.close()

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you used histograms to visualize various aspects of the dataset, focusing on:
#
# - Distribution of compensation, coding experience, and work hours.
#
# - Relationships in compensation across age groups and work status.
#
# - Composition of data by desired databases and work environments.
#
# - Comparisons of job satisfaction across years of experience.
#
# Histograms helped reveal patterns and distributions in the data, enhancing your understanding of developer demographics and preferences.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
