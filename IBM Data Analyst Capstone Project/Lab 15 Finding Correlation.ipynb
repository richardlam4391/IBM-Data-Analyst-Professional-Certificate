# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Correlation**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform exploratory data analysis (EDA). You will examine the distribution of the data, identify outliers, and determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# - Identify the distribution of compensation data in the dataset.
#
# - Remove outliers to refine the dataset.
#
# - Identify correlations between various features in the dataset.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# ##### Step 1: Install and Import Required Libraries

# %%
# Install the necessary libraries
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2: Load the Dataset

# %%
# Load the dataset from the given URL
file_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"
df = pd.read_csv(file_url)

# Display the first few rows to understand the structure of the dataset
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# <h3>Step 3: Analyze and Visualize Compensation Distribution</h3>

# %% [markdown]
# **Task**: Plot the distribution and histogram for `ConvertedCompYearly` to examine the spread of yearly compensation among respondents.

# %%
df = df[df["ConvertedCompYearly"] <= 500000]
plt.figure(figsize=(10,6))
sns.histplot(df["ConvertedCompYearly"], bins=20, color='blue')
plt.title("Histogram of ConvertedCompYearly")
plt.xlabel("Converted Comp Yearly")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h3>Step 4: Calculate Median Compensation for Full-Time Employees</h3>

# %% [markdown]
# **Task**: Filter the data to calculate the median compensation for respondents whose employment status is "Employed, full-time."

# %%
full_time = df[df["Employment"] == "Employed, full-time"]
median_comp = full_time["ConvertedCompYearly"].median()
median_comp
# Out:
# np.float64(69814.0)

# %% [markdown]
# <h3>Step 5: Analyzing Compensation Range and Distribution by Country</h3>

# %% [markdown]
# Explore the range of compensation in the ConvertedCompYearly column by analyzing differences across countries. Use box plots to compare the compensation distributions for each country to identify variations and anomalies within each region, providing insights into global compensation trends.

# %%
df['ConvertedCompYearly'] = pd.to_numeric(df['ConvertedCompYearly'], errors='coerce')
df_clean = df.dropna(subset=['Country', 'ConvertedCompYearly'])
df_stats = df_clean.groupby('Country')['ConvertedCompYearly'].agg(
    Median='median',
    Q1=lambda x: x.quantile(0.25),
    Q3=lambda x: x.quantile(0.75),
    Count='count'
).reset_index()
df_stats['IQR'] = df_stats['Q3'] - df_stats['Q1']
df_stats['Lower Bound'] = (df_stats['Q1'] - 1.5 * df_stats['IQR']).clip(lower=0)
df_stats['Upper Bound'] = df_stats['Q3'] + 1.5 * df_stats['IQR']
df_top10_stats = df_stats.sort_values(by='Median', ascending=False).head(10)
top10_countries = df_top10_stats['Country'].tolist()
outlier_counts = {}
for country in top10_countries:
    c_data = df_clean[df_clean['Country'] == country]['ConvertedCompYearly']
    row = df_top10_stats[df_top10_stats['Country'] == country].iloc[0]
    outliers = c_data[(c_data < row['Lower Bound']) | (c_data > row['Upper Bound'])]
    outlier_counts[country] = len(outliers)
df_top10_stats['Outliers Count'] = df_top10_stats['Country'].map(outlier_counts)
print("--- Top 10 Countries Summary Statistics ---")
print(df_top10_stats[['Country', 'Median', 'Q1', 'Q3', 'IQR', 'Lower Bound', 'Upper Bound', 'Outliers Count']].to_string(index=False))
df_plot = df_clean[df_clean['Country'].isin(top10_countries)]
plt.figure(figsize=(10, 6))
sns.boxplot(
    data=df_plot, 
    x='ConvertedCompYearly', 
    y='Country', 
    order=top10_countries,
    hue='Country',
    palette='viridis',
    legend=False,
)
plt.title('Top 10 Countries by Median Compensation (Outliers Hidden for Clarity)', fontsize=14, pad=15)
plt.xlabel('Annual Compensation (USD)')
plt.ylabel('Country')
plt.tight_layout()
plt.show()
# Out:
# --- Top 10 Countries Summary Statistics ---
#                  Country   Median       Q1       Q3     IQR  Lower Bound  Upper Bound  Outliers Count
# United States of America 140000.0 100000.0 187000.0 87000.0          0.0     317500.0             177
#      Antigua and Barbuda 126120.0 126120.0 126120.0     0.0     126120.0     126120.0               0
#                  Andorra 123517.0  88610.0 158424.0 69814.0          0.0     263145.0               0
#                   Israel 113334.0  80953.0 145715.0 64762.0          0.0     242858.0               3
#              Switzerland 111417.0  89134.0 142614.0 53480.0       8914.0     222834.0              15
#                Singapore 103482.0  75578.5 172394.5 96816.0          0.0     317618.5               2
#               Luxembourg  96288.0  68740.0 126202.0 57462.0          0.0     212395.0               1
#                Australia  94804.5  72673.0 118919.0 46246.0       3304.0     188288.0              28
# ...

# %% [markdown]
# <h3>Step 6: Removing Outliers from the Dataset</h3>

# %% [markdown]
# **Task**: Create a new DataFrame by removing outliers from the `ConvertedCompYearly` column to get a refined dataset for correlation analysis.

# %%
comp = df["ConvertedCompYearly"].dropna()
Q1 = comp.quantile(0.25)
Q3 = comp.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df_no_outliers = df[(df["ConvertedCompYearly"] >= lower_bound) &
                    (df["ConvertedCompYearly"] <= upper_bound)]
print("Original dataset size:", len(df))
print("Cleaned dataset size:", len(df_no_outliers))
print("Rows removed:", len(df) - len(df_no_outliers))
# Out:
# Original dataset size: 23310
# Cleaned dataset size: 22404
# Rows removed: 906

# %% [markdown]
# <h3>Step 7: Finding Correlations Between Key Variables</h3>

# %% [markdown]
# **Task**: Calculate correlations between `ConvertedCompYearly`, `WorkExp`, and `JobSatPoints_1`. Visualize these correlations with a heatmap.

# %%
cols = ["ConvertedCompYearly", "WorkExp", "JobSatPoints_1"]
df_corr = df[cols].dropna()
corr_matrix = df_corr.corr()
print(corr_matrix)
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='viridis')
plt.title("Correlation Heatmap: Compensation, Work Experience, Job Satisfaction")
plt.show()
# Out:
#                      ConvertedCompYearly   WorkExp  JobSatPoints_1
# ConvertedCompYearly             1.000000  0.383411       -0.042878
# WorkExp                         0.383411  1.000000       -0.030222
# JobSatPoints_1                 -0.042878 -0.030222        1.000000

# %% [markdown]
# <h3>Step 8: Scatter Plot for Correlations</h3>

# %% [markdown]
# **Task**: Create scatter plots to examine specific correlations between `ConvertedCompYearly` and `WorkExp`, as well as between `ConvertedCompYearly` and `JobSatPoints_1`.

# %%
df_scatter = df[["ConvertedCompYearly", "WorkExp", "JobSatPoints_1"]].dropna()
plt.figure(figsize=(10, 5))
sns.scatterplot(
    data=df_scatter,
    x="WorkExp",
    y="ConvertedCompYearly",
    color="blue"
)
plt.title("ConvertedCompYearly vs WorkExp")
plt.xlabel("Work Experience")
plt.ylabel("Yearly Compensation")
plt.show()
plt.figure(figsize=(10, 5))
sns.scatterplot(
    data=df_scatter,
    x="JobSatPoints_1",
    y="ConvertedCompYearly",
    color="gold"
)
plt.title("ConvertedCompYearly vs JobSatPoints_1")
plt.xlabel("Job Satisfaction Score")
plt.ylabel("Yearly Compensation")
plt.show()

# %% [markdown]
# <h3>Summary</h3>

# %% [markdown]
# In this lab, you practiced essential skills in correlation analysis by:
#
# - Examining the distribution of yearly compensation with histograms and box plots.
# - Detecting and removing outliers from compensation data.
# - Calculating correlations between key variables such as compensation, work experience, and job satisfaction.
# - Visualizing relationships with scatter plots and heatmaps to gain insights into the associations between these features.
#
# By following these steps, you have developed a solid foundation for analyzing relationships within the dataset.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
